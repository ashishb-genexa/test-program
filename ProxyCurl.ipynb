# %%
import requests

api_key = 
headers = {'Authorization': 'Bearer ' + api_key}
api_endpoint = 
params = {
    'company_domain': 'Adam Noble Group',
    'first_name': 'Jeff',
    'similarity_checks': 'include',
    'enrich_profile': 'enrich',
    'title': '',
    'last_name': 'Adam',
}
response = requests.get(api_endpoint,
                        params=params,
                        headers=headers)

# %%
response.json()
# Out:
# {'url': 'https://www.linkedin.com/in/jeffadam',
#  'name_similarity_score': 1.0,
#  'company_similarity_score': 1.0,
#  'title_similarity_score': 0.0,
#  'location_similarity_score': 0.0,
#  'profile': {'public_identifier': 'jeffadam',
#   'profile_pic_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/jeffadam/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20250306%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20250306T124952Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=28a796cf1f29f45402f78cf63cd4d144f7b65487490ad75feaad78ad41eb101e',
#   'background_cover_image_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/jeffadam/cover?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20250306%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20250306T124952Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=ad3804e79e3c31f4a31954e1604f65890206eecb654ef10a9d796828a92b1a1a',
# ...

# %% [markdown]
# ## Work Email Endpoint

# %%
import requests

api_key = 
headers = {'Authorization': 'Bearer ' + api_key}
api_endpoint = 'https://nubela.co/proxycurl/api/linkedin/profile/email'
params = {
    'linkedin_profile_url': 'https://www.linkedin.com/in/jeff-ackerman-54439939',
    'callback_url': 'https://webhook.site/29e12f17-d5a2-400a-9d08-42ee9d83600a',
}
response = requests.get(api_endpoint,
                        params=params,
                        headers=headers)

# %%
response.json()
# Out:
# {'email_queue_count': 0}

# %%
para ="Jeff Ackerman + Houlihan Lokey"

# %%
import src.util.sqllite_helper as db_manager
import json
str_sql="INSERT INTO proxyCurl_responses (api_name, input_para, result) VALUES (?, ?, ?)"
db_manager.execute_sql(str_sql,["proxycurl", para, json.dumps(response.json())])

# %% [markdown]
# ## Person search Endpoint

# %%
import requests

api_key = 
headers = {'Authorization': 'Bearer ' + api_key}
api_endpoint = 'https://nubela.co/proxycurl/api/v2/search/person'
params = {
    
    'first_name': 'Jeff',
    'last_name': 'Adam',
    'current_company_name': 'Adam Noble Group',   
    'enrich_profiles': 'enrich',
    'use_cache': 'if-recent',
}
response = requests.get(api_endpoint,
                        params=params,
                        headers=headers)

# %%
response.json()
# Out:
# {'results': [{'linkedin_profile_url': 'https://www.linkedin.com/in/jeffadam',
#    'profile': {'public_identifier': 'jeffadam',
#     'profile_pic_url': 'https://media.licdn.com/dms/image/v2/D4E03AQFEZSn6RcAcsA/profile-displayphoto-shrink_800_800/profile-displayphoto-shrink_800_800/0/1644097992652?e=1746662400&v=beta&t=Ewjh066Mps0WDUtbUIBticuMlLfdvytUWYmE2Kd1wmU',
#     'background_cover_image_url': 'https://media.licdn.com/dms/image/v2/C4E16AQF37AkHH5hQnw/profile-displaybackgroundimage-shrink_200_800/profile-displaybackgroundimage-shrink_200_800/0/1630618885005?e=1746662400&v=beta&t=2gfGxJExnpcL8CJ7drPCgWmtWEpA7qSI7jmRM1y2zmE',
#     'first_name': 'Jeff',
#     'last_name': 'Adam',
#     'full_name': 'Jeff Adam',
#     'follower_count': 3708,
#     'occupation': 'Investor, President, M&A Advisor, Valuations, Author, Speaker, Business Brokerage at ADAM NOBLE GROUP LLC',
# ...
